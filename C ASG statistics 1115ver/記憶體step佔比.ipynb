# %%
sample_dict = {
    'Dofloo': ['60f879ed44de37351c973f01d0d77f79'],  # 只先使用這個 dof sample  0046a78514a658b9b7a4e29e8581f85b
    'Xorddos': ['0aefb67c01a24d05351b093455203fa2'], # 只先使用這個 xor sample
    'Darlloz': ['dfeb77cb0ba28ac3ba4be55d7bc91fad'], # 只先使用這個 dar sample
    'Gafgyt': ['933e9eff97f50b196b2bb0fef499640e'],  # 只先使用這個 gaf sample
    'Luabot': ['a220940db4be6878e47b74403a8079a1'],  # 只先使用這個 lua sample
    'Lupper': ['a220940db4be6878e47b74403a8079a1'],  # 只先使用這個 lua sample
    'Kaiten': ['19bc282193a9a792aeab3eb826c73976'],  # 只先使用這個 kai sample
    'Turla': ['19fbd8cbfb12482e8020a887d6427315'],   # 只先使用這個 tur sample
    'BPFDoor': ['5faab159397964e630c4156f8852bcc6ee46df1cdd8be2a8d3f3d8e5980f3bb3'],
    'Conti': ['95776f31cbcac08eb3f3e9235d07513a6d7a6bf9f1b7f3d400b2cf0afdb088a7'],
    'ChinaZ': ['14afd7d319cf271a7d871f297a27eac388d7f0381a1fc0691b18a8dd15ddf327'],
    'Defray777': ['da3bb9669fb983ad8d2ffc01aab9d56198bd9cedf2cc4387f19f4604a070a9b5'],
    'Demonbot': ['9de853e88ba363b124dfce61bc766f8f42c84340c7bd2f4195808434f4ed81e3'],
    'EvilGnome': ['7ffab36b2fa68d0708c82f01a70c8d10614ca742d838b69007f5104337a4b869'],
    'FontOnLake': ['602c435834d796943b1e547316c18a9a64c68f032985e7a5a763339d82598915'],
    'HCRootkit': ['6187541be6d2a9d23edaa3b02c50aea644c1ac1a80ff3e4ddd441b0339e0dd1b'],
    'KEYPLUG': ['99b36963f0e93a5c59cbd205d102f6b850f02f5e74ac4f66257b6f38d9c9ef5a'],
    'Lightning': ['fd285c2fb4d42dde23590118dba016bf5b846625da3abdbe48773530a07bcd1e'],
    'Melofee': ['407ab8618fed74fdb5fd374f3ed4a2fd9e8ea85631be2787e2ad17200f0462b8'],
    'XMRigMiner': ['01a1aa3cd4831197c4c97164d721dca41bbec2ba98ec6813979dcb2820ab44e1'],
    '': [''],
}
# samplename_lst = sample_dict[family]
# print('samplename:', samplename_lst)

for family, s in sample_dict.items():
    s = s[0]
    print(family, s)
    with open():
    break
# Out:
# Dofloo 60f879ed44de37351c973f01d0d77f79

# %%
steplist = [['malware', '/proc/self/exe', 'readlink'],
 ['malware', 'Memory Address', 'mprotect'],
 ['malware', 'Memory Address', 'munmap'],
 ['malware', 'uname', 'exec'],
 ['malware', 'Memory Address', 'brk'],
 ['malware', 'Memory Address', 'arch_prctl'],
 ['malware', 'Memory Address', 'set_tid_address'],
 ['malware', 'Memory Address', 'set_robust_list'],
 ['malware', '/prober', 'getcwd'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', 'sh', 'clone'],
 ['malware', 'sh', 'wait4'],
 ['malware', '1531', 'clone'],
 ['malware', 'status:0', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1515', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/sed', 'stat'],
 ['sh', '/usr/local/bin/sed', 'stat'],
 ['sh', '/usr/sbin/sed', 'stat'],
 ['sh', '/usr/bin/sed', 'stat'],
 ['sh', '/sbin/sed', 'stat'],
 ['sh', '/bin/sed', 'stat'],
 ['sh', 'sed', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:0', 'exit_group'],
 ['sed', 'Memory Address', 'brk'],
 ['sed', 'Memory Address', 'mprotect'],
 ['sed', 'Memory Address', 'arch_prctl'],
 ['sed', 'Memory Address', 'munmap'],
 ['sed', 'Memory Address', 'set_tid_address'],
 ['sed', 'Memory Address', 'set_robust_list'],
 ['sed', '8192*1024 bytes', 'prlimit64'],
 ['sed', '/sys/fs/selinux', 'statfs'],
 ['sed', '/selinux', 'statfs'],
 ['sed', '/etc/selinux/config', 'access'],
 ['sed', 'Memory Address', 'futex'],
 ['sed', '/etc/rc.local', 'open'],
 ['sed', 'Permission:0700', 'umask'],
 ['sed', 'PID:1516', 'getpid'],
 ['sed', 'Permission:022', 'umask'],
 ['sed', '/etc/sedRrSM8d', 'fcntl'],
 ['sed', '/etc/sedRrSM8d', 'fstat'],
 ['sed', '/etc/sedRrSM8d', 'write'],
 ['sed', '/etc/sedRrSM8d', 'fchown'],
 ['sed', '/etc/sedRrSM8d', 'fchmod'],
 ['/etc/sedRrSM8d', '/etc/rc.local', 'rename'],
 ['sed', 'status:0', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1517', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/sed', 'stat'],
 ['sh', '/usr/local/bin/sed', 'stat'],
 ['sh', '/usr/sbin/sed', 'stat'],
 ['sh', '/usr/bin/sed', 'stat'],
 ['sh', '/sbin/sed', 'stat'],
 ['sh', '/bin/sed', 'stat'],
 ['sh', 'sed', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:1', 'exit_group'],
 ['sed', 'Memory Address', 'brk'],
 ['sed', 'Memory Address', 'mprotect'],
 ['sed', 'Memory Address', 'arch_prctl'],
 ['sed', 'Memory Address', 'munmap'],
 ['sed', 'Memory Address', 'set_tid_address'],
 ['sed', 'Memory Address', 'set_robust_list'],
 ['sed', '8192*1024 bytes', 'prlimit64'],
 ['sed', '/sys/fs/selinux', 'statfs'],
 ['sed', '/selinux', 'statfs'],
 ['sed', '/etc/selinux/config', 'access'],
 ['sed', 'Memory Address', 'futex'],
 ['sed', 'status:1', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1519', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/sed', 'stat'],
 ['sh', '/usr/local/bin/sed', 'stat'],
 ['sh', '/usr/sbin/sed', 'stat'],
 ['sh', '/usr/bin/sed', 'stat'],
 ['sh', '/sbin/sed', 'stat'],
 ['sh', '/bin/sed', 'stat'],
 ['sh', 'sed', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:0', 'exit_group'],
 ['sed', 'Memory Address', 'brk'],
 ['sed', 'Memory Address', 'mprotect'],
 ['sed', 'Memory Address', 'arch_prctl'],
 ['sed', 'Memory Address', 'munmap'],
 ['sed', 'Memory Address', 'set_tid_address'],
 ['sed', 'Memory Address', 'set_robust_list'],
 ['sed', '8192*1024 bytes', 'prlimit64'],
 ['sed', '/sys/fs/selinux', 'statfs'],
 ['sed', '/selinux', 'statfs'],
 ['sed', '/etc/selinux/config', 'access'],
 ['sed', 'Memory Address', 'futex'],
 ['sed', '/etc/rc.local', 'open'],
 ['sed', 'Permission:0700', 'umask'],
 ['sed', 'PID:1520', 'getpid'],
 ['sed', 'Permission:022', 'umask'],
 ['sed', '/etc/sed7WeJOi', 'fcntl'],
 ['sed', '/etc/sed7WeJOi', 'fstat'],
 ['sed', '/etc/sed7WeJOi', 'write'],
 ['sed', '/etc/sed7WeJOi', 'fchown'],
 ['sed', '/etc/sed7WeJOi', 'fchmod'],
 ['/etc/sed7WeJOi', '/etc/rc.local', 'rename'],
 ['sed', 'status:0', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1521', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/sed', 'stat'],
 ['sh', '/usr/local/bin/sed', 'stat'],
 ['sh', '/usr/sbin/sed', 'stat'],
 ['sh', '/usr/bin/sed', 'stat'],
 ['sh', '/sbin/sed', 'stat'],
 ['sh', '/bin/sed', 'stat'],
 ['sh', 'sed', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:0', 'exit_group'],
 ['sed', 'Memory Address', 'brk'],
 ['sed', 'Memory Address', 'mprotect'],
 ['sed', 'Memory Address', 'arch_prctl'],
 ['sed', 'Memory Address', 'munmap'],
 ['sed', 'Memory Address', 'set_tid_address'],
 ['sed', 'Memory Address', 'set_robust_list'],
 ['sed', '8192*1024 bytes', 'prlimit64'],
 ['sed', '/sys/fs/selinux', 'statfs'],
 ['sed', '/selinux', 'statfs'],
 ['sed', '/etc/selinux/config', 'access'],
 ['sed', 'Memory Address', 'futex'],
 ['sed', '/etc/rc.local', 'open'],
 ['sed', 'Permission:0700', 'umask'],
 ['sed', 'PID:1522', 'getpid'],
 ['sed', 'Permission:022', 'umask'],
 ['sed', '/etc/sedSQpmdi', 'fcntl'],
 ['sed', '/etc/sedSQpmdi', 'fstat'],
 ['sed', '/etc/sedSQpmdi', 'write'],
 ['sed', '/etc/sedSQpmdi', 'fchown'],
 ['sed', '/etc/sedSQpmdi', 'fchmod'],
 ['/etc/sedSQpmdi', '/etc/rc.local', 'rename'],
 ['sed', 'status:0', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1523', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/sed', 'stat'],
 ['sh', '/usr/local/bin/sed', 'stat'],
 ['sh', '/usr/sbin/sed', 'stat'],
 ['sh', '/usr/bin/sed', 'stat'],
 ['sh', '/sbin/sed', 'stat'],
 ['sh', '/bin/sed', 'stat'],
 ['sh', 'sed', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:2', 'exit_group'],
 ['sed', 'Memory Address', 'brk'],
 ['sed', 'Memory Address', 'mprotect'],
 ['sed', 'Memory Address', 'arch_prctl'],
 ['sed', 'Memory Address', 'munmap'],
 ['sed', 'Memory Address', 'set_tid_address'],
 ['sed', 'Memory Address', 'set_robust_list'],
 ['sed', '8192*1024 bytes', 'prlimit64'],
 ['sed', '/sys/fs/selinux', 'statfs'],
 ['sed', '/selinux', 'statfs'],
 ['sed', '/etc/selinux/config', 'access'],
 ['sed', 'Memory Address', 'futex'],
 ['sed', '/etc/rc.d/rc.local', 'open'],
 ['sed', 'status:2', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1525', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/sed', 'stat'],
 ['sh', '/usr/local/bin/sed', 'stat'],
 ['sh', '/usr/sbin/sed', 'stat'],
 ['sh', '/usr/bin/sed', 'stat'],
 ['sh', '/sbin/sed', 'stat'],
 ['sh', '/bin/sed', 'stat'],
 ['sh', 'sed', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:2', 'exit_group'],
 ['sed', 'Memory Address', 'brk'],
 ['sed', 'Memory Address', 'mprotect'],
 ['sed', 'Memory Address', 'arch_prctl'],
 ['sed', 'Memory Address', 'munmap'],
 ['sed', 'Memory Address', 'set_tid_address'],
 ['sed', 'Memory Address', 'set_robust_list'],
 ['sed', '8192*1024 bytes', 'prlimit64'],
 ['sed', '/sys/fs/selinux', 'statfs'],
 ['sed', '/selinux', 'statfs'],
 ['sed', '/etc/selinux/config', 'access'],
 ['sed', 'Memory Address', 'futex'],
 ['sed', '/etc/init.d/boot.local', 'open'],
 ['sed', 'status:2', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1527', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/rm', 'stat'],
 ['sh', '/usr/local/bin/rm', 'stat'],
 ['sh', '/usr/sbin/rm', 'stat'],
 ['sh', '/usr/bin/rm', 'stat'],
 ['sh', '/sbin/rm', 'stat'],
 ['sh', '/bin/rm', 'stat'],
 ['sh', 'rm', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:0', 'exit_group'],
 ['rm', 'Memory Address', 'brk'],
 ['rm', 'Memory Address', 'mprotect'],
 ['rm', 'Memory Address', 'arch_prctl'],
 ['rm', 'Memory Address', 'munmap'],
 ['rm', 'status:0', 'exit_group'],
 ['sh', 'Memory Address', 'brk'],
 ['sh', 'Memory Address', 'mprotect'],
 ['sh', 'Memory Address', 'arch_prctl'],
 ['sh', 'Memory Address', 'munmap'],
 ['sh', 'UID:0', 'getuid'],
 ['sh', 'GID:0', 'getgid'],
 ['sh', 'PID:1529', 'getpid'],
 ['sh', 'UID:0', 'geteuid'],
 ['sh', 'PID:1514', 'getppid'],
 ['sh', '/prober', 'stat'],
 ['sh', '.', 'stat'],
 ['sh', 'GID:0', 'getegid'],
 ['sh', '/usr/local/sbin/rm', 'stat'],
 ['sh', '/usr/local/bin/rm', 'stat'],
 ['sh', '/usr/sbin/rm', 'stat'],
 ['sh', '/usr/bin/rm', 'stat'],
 ['sh', '/sbin/rm', 'stat'],
 ['sh', '/bin/rm', 'stat'],
 ['sh', 'rm', 'exec'],
 ['sh', 'NO_PID', 'wait4'],
 ['sh', 'status:0', 'exit_group'],
 ['rm', 'Memory Address', 'brk'],
 ['rm', 'Memory Address', 'mprotect'],
 ['rm', 'Memory Address', 'arch_prctl'],
 ['rm', 'Memory Address', 'munmap'],
 ['rm', 'status:0', 'exit_group'],
 ['1531', 'Memory Address', 'set_robust_list'],
 ['1531', 'Memory Address', 'mprotect'],
 ['1531', '1532', 'clone'],
 ['1531', '1533', 'clone'],
 ['1531', '/dev/urandom', 'open'],
 ['1531', '/dev/urandom', 'read'],
 ['1531', 'NIC', 'read'],
 ['1531', '/etc/resolv.conf', 'open'],
 ['1531', '/etc/resolv.conf', 'fstat'],
 ['1531', '/etc/resolv.conf', 'read'],
 ['1531', 'Memory Address', 'munmap'],
 ['1531', 'uname', 'exec'],
 ['1531', '218.60.25.91:10210', 'connect'],
 ['218.60.25.91:10210', '1531', 'getsockopt'],
 ['1531', '218.60.25.91:10210', 'fstat'],
 ['1531', '218.60.25.91:10210', 'mmap'],
 ['1531', 'Sleep Duration', 'nanosleep'],
 ['1531', '/etc/resolv.conf', 'stat'],
 ['1531', 'Memory Address', 'futex'],
 ['1532', 'Memory Address', 'set_robust_list'],
 ['1532', '/proc/net/dev', 'open'],
 ['1532', '/proc/net/dev', 'lseek'],
 ['1532', '/proc/net/dev', 'read'],
 ['1532', 'Timestamp', 'time'],
 ['1532', '/sys/devices/system/cpu/online', 'open'],
 ['1532', '/sys/devices/system/cpu/online', 'read'],
 ['1532', 'Sleep Duration', 'nanosleep'],
 ['1532', '218.60.25.91:10210', 'mmap'],
 ['1532', 'Memory Address', 'munmap'],
 ['1532', 'Memory Address', 'mprotect'],
 ['1532', '/proc/stat', 'open'],
 ['1532', '/proc/stat', 'fstat'],
 ['1532', '/proc/stat', 'read'],
 ['1532', 'NO_SOCKET', 'send'],
 ['1533', 'Memory Address', 'set_robust_list'],
 ['1533', 'Sleep Duration', 'nanosleep'],
 ['1533', '218.60.25.91:10210', 'mmap'],
 ['1533', 'Memory Address', 'munmap'],
 ['1533', 'Memory Address', 'mprotect'],
 ['1533', '/etc/resolv.conf', 'open'],
 ['1533', '/etc/resolv.conf', 'fstat'],
 ['1533', '/etc/resolv.conf', 'read'],
 ['1533', 'uname', 'exec'],
 ['1533', '/etc/resolv.conf', 'stat'],
 ['1533', '/etc/nsswitch.conf', 'open'],
 ['1533', '/etc/nsswitch.conf', 'fstat'],
 ['1533', '/etc/nsswitch.conf', 'read'],
 ['1533', '218.60.25.91:10210', 'fstat'],
 ['1533', '218.60.25.91:10210', 'read'],
 ['1533', '/etc/host.conf', 'open'],
 ['1533', '/etc/host.conf', 'fstat'],
 ['1533', '/etc/host.conf', 'read'],
 ['1533', 'Memory Address', 'futex'],
 ['1533', '/etc/hosts', 'open'],
 ['1533', '/etc/hosts', 'fstat'],
 ['1533', '/etc/hosts', 'read'],
 ['1533', '127.0.0.53:53', 'connect'],
 ['1533', 'Timestamp', 'gettimeofday'],
 ['1533', '127.0.0.53:53', 'send'],
 ['1533', 'Memory Address', 'set_tid_address'],
 ['1533', '8192*1024 bytes', 'prlimit64'],
 ['1533', '0.0.0.0:1020', 'connect']]

# %%
lenx = len(steplist)
len_memory_dst = 0

for step in steplist:
    (_, dst, _) = step
    if dst == 'Memory Address':
        len_memory_dst += 1
print('lex_memory_dst:', len_memory_dst, '| Total:',lenx)
# Out:
# lex_memory_dst: 100 | Total: 371

# %%
if '-> Memory Address' in line:
    len_memory_dst += 1

# %%
sample_dict = {
    'BPFDoor': ['5faab159397964e630c4156f8852bcc6ee46df1cdd8be2a8d3f3d8e5980f3bb3'],
    'Conti': ['95776f31cbcac08eb3f3e9235d07513a6d7a6bf9f1b7f3d400b2cf0afdb088a7'],
    'ChinaZ': ['14afd7d319cf271a7d871f297a27eac388d7f0381a1fc0691b18a8dd15ddf327'],
    'Defray777': ['da3bb9669fb983ad8d2ffc01aab9d56198bd9cedf2cc4387f19f4604a070a9b5'],
    'Demonbot': ['9de853e88ba363b124dfce61bc766f8f42c84340c7bd2f4195808434f4ed81e3'],
    'EvilGnome': ['7ffab36b2fa68d0708c82f01a70c8d10614ca742d838b69007f5104337a4b869'],
    'FontOnLake': ['602c435834d796943b1e547316c18a9a64c68f032985e7a5a763339d82598915'],
    'HCRootkit': ['6187541be6d2a9d23edaa3b02c50aea644c1ac1a80ff3e4ddd441b0339e0dd1b'],
    'KEYPLUG': ['99b36963f0e93a5c59cbd205d102f6b850f02f5e74ac4f66257b6f38d9c9ef5a'],
    'Lightning': ['fd285c2fb4d42dde23590118dba016bf5b846625da3abdbe48773530a07bcd1e'],
    'Melofee': ['407ab8618fed74fdb5fd374f3ed4a2fd9e8ea85631be2787e2ad17200f0462b8'],
    'XMRigMiner': ['01a1aa3cd4831197c4c97164d721dca41bbec2ba98ec6813979dcb2820ab44e1'],
}
# samplename_lst = sample_dict[family]
# print('samplename:', samplename_lst)

ratio_list = []

for family, s in sample_dict.items():
    s = s[0]
    # print(family, s)
    with open(f"./saved_pkl/{family}/{s}_steplist.txt", "r") as f:
        content = f.read()

    steplist = content.split('\n')
    lenx = len(steplist)
    len_memory_dst = 0
    for line in steplist:
        if '-> Memory Address' in line:
            len_memory_dst += 1
    ratio = len_memory_dst/lenx
    print(family, '=> lex_memory_dst:', len_memory_dst, '| Total:',lenx, '| ratio:', f"{ratio*100:.0f}%")
    ratio_list.append(ratio)
    del content, steplist
    # break
# Out:
# BPFDoor => lex_memory_dst: 30 | Total: 75 | ratio: 40%
# Conti => lex_memory_dst: 7 | Total: 12 | ratio: 58%
# ChinaZ => lex_memory_dst: 101 | Total: 597 | ratio: 17%
# Defray777 => lex_memory_dst: 11 | Total: 41 | ratio: 27%
# Demonbot => lex_memory_dst: 308 | Total: 1437 | ratio: 21%
# EvilGnome => lex_memory_dst: 23 | Total: 58330 | ratio: 0%
# FontOnLake => lex_memory_dst: 27 | Total: 74 | ratio: 36%
# HCRootkit => lex_memory_dst: 1 | Total: 3 | ratio: 33%
# KEYPLUG => lex_memory_dst: 9 | Total: 29 | ratio: 31%
# Lightning => lex_memory_dst: 11 | Total: 37 | ratio: 30%
# Melofee => lex_memory_dst: 21 | Total: 1113 | ratio: 2%
# XMRigMiner => lex_memory_dst: 23 | Total: 495 | ratio: 5%

# %%
# ratio_list += [100/371] # dolfoo
from statistics import mean 
mean(ratio_list)
# Out:
# 0.2520192036964217
