# %%
import glob

folder_path = './'
blacklist = ['skip', 'exclude', 'ignore']  # List of strings to exclude from search

# Get a list of all .html files under the folder_path, excluding those that contain a string in the blacklist
# f"{folder_path}/**/*.html"
html_files = [f for f in glob.glob(f"{folder_path}/**/*.html", recursive=True) if not any(black in f for black in blacklist)]
pdf_files  = [f for f in glob.glob(f"{folder_path}/**/*.pdf", recursive=True) if not any(black in f for black in blacklist)]
html_files.extend(pdf_files)
html_files.sort()

print(html_files)
# Out:
# ['.\\Darlloz blogs.cisco.com - Including Malware (analysis).html', '.\\Darlloz community.broadcom.com - Endpoint Protection Symantec Enterprise (news).html', '.\\Darlloz giac.org - introduction linux based malware (tech).pdf', '.\\Darlloz icc17 - IoT Sandbox To Analysis IoT malware Zollard (analysis).pdf', '.\\Darlloz trendmicro.com - UNIX_DARLLOZ.A (tech).html', '.\\Darlloz trendmicro.com - Worm_Linux_DARLLOZ.AA (tech).html', '.\\Gafgyt fortinet.com - Linux Gafgyt.B!tr Exploits Netcore Vulnerability (analysis).html', '.\\Gafgyt nozominetworks.com - Could Threat Actors Be Downgrading Their Malware to Evade Detection (analysis).html', '.\\Gafgyt resources.securityscorecard.com - A Detailed Analysis Of The Gafgyt Malware Targeting IoT Devices (analysis).pdf', '.\\Gafgyt sectrio.com - Gafgyt Backdoor Malware report (analysis).pdf', '.\\Gafgyt trendmicro.com - GAFGYT Threat Encyclopedia (tech).html', '.\\Gafgyt unit42.paloaltonetworks.com - Multi-exploit IoT_Linux Botnets Mirai and Gafgyt Target Apache Struts (analysis).html', '.\\Gafgyt unit42.paloaltonetworks.com - Unit 42 Finds New Mirai and Gafgyt IoT_Linux Botnet Campaigns (analysis).html', '.\\Gafgyt wikipedia.org - Wikipedia BASHLITE (tech).html', '.\\Kaiten fsecure.com - Backdoor OSX Tsunami.A (tech).html', '.\\Kaiten lacework.com - The Kek Security Network (tech).html', '.\\Kaiten tarlogic.com - Attackers Abuse MobileIron’s RCE to deliver Kaiten (analysis).html', '.\\Kaiten trendmicro.com - Exposed Docker Server Abused to Drop Cryptominer DDoS Bot (campaign).html', '.\\Kaiten trendmicro.com2 - Backdoor.Linux.KAITEN.AMV Threat Encyclopedia (tech).html', '.\\Luabot cyber.nj.gov - NJCCIC Threat Profile LuaBot (news).html', '.\\Luabot malwaremustdie.org - 2016 Linux_LuaBot IoT botnet as service (analysis).html', '.\\Luabot microsoft.com - Backdoor_Linux_Luabot.A threat description (tech).html', '.\\Luabot news.softpedia.com - LuaBot Is the First DDoS Malware Coded in Lua Targeting Linux Platforms (news).html', '.\\Luabot securityaffairs.co - LuaBot is the first Linux DDoS botnet written in Lua Language (analysis).html', '.\\Luabot trendmicro.com - New Linux Malware Exploits CGI Vulnerability (tech).html', '.\\Luabot w00tsec.blogspot - LuaBot Malware targeting cable modems (analysis).html', '.\\Luabot xforce.ibmcloud.com - LuaBot Linux_IoT Malware (tech).html', '.\\Turla kcm.trellix.com - Trellix Insights The Penquin Turla (tech).html', '.\\Turla leonardo.com - Malware Technical Insight Turla Penquin_x64 (analysis).pdf', '.\\Turla securelist.com - The Penquin Turla (analysis).html', '.\\Turla trendmicro.com - BKDR_TURLA.YKX Threat Encyclopedia (tech).html', '.\\dofloo bleepingcomputer.com - Exposed Docker APIs Abused by DDoS (news).html', '.\\dofloo blog.malwaremustdie.org - Reversing an ARM arch ELF (analysis).html', '.\\dofloo blog.syscall.party - Analysing the new Linux_AES.DDoS IoT malware (analysis).html', '.\\dofloo securityaffairs.co - AESDDoS exploits CVE-2019-3396 flaw (news).html', '.\\dofloo trendmicro.com - Threat Encyclopedia (tech).html', '.\\lupper securelist.com - Linux.Lupper reports (news).html', '.\\lupper spamlaws.com -  Lupper Worm (analysis).html', '.\\lupper trendmicro.com - Lupil_Lupper Worm Vulnerability - Threat Encyclopedia (tech).html', '.\\lupper web.archive.org - Linux_Lupper.worm (tech).html', '.\\xorddos cdnetworks.com- Understanding a XOR.DDoS Attack (tech).html', '.\\xorddos crowdstrike.com - Linux-Targeted Malware Increases by 35p in 2021 (news).html', '.\\xorddos intezer.com - Linux Backdoor RedXOR Likely Operated by Chinese Nation-State (analysis).html', '.\\xorddos microsoft.com - A deeper look at the stealthy DDoS malware targeting Linux devices (analysis).html', '.\\xorddos trendmicro.com - Threat Encyclopedia (tech).html', '.\\xorddos trendmicro.com - XORDDoS, Kaiji Variants Target Exposed Docker Servers (analysis).html']

# %%
def read_until(sent:str, skipword:str):
    start = sent.find(skipword)
    end = start + len(skipword)
    return sent[end:].strip()

# read_until('.\\Darlloz blogs.cisco.com - Including Malware (analysis).html', 'Darlloz')

def parse(filename:str, familyname):
    if filename.endswith('html'):
        filename = filename.split('.html')[0]
    else:
        filename = filename.split('.pdf')[0]
    filename = read_until(filename, familyname) # filename = ''.join(filename.split(familyname)[1:])
    # print(filename)
    # website, *title = filename.split('-')[0]
    # title = ''.join(title) # bugs
    website = filename.split('-')[0]
    title   = filename.split('-')[1:]
    title = ''.join(title)
    # print(website, title)
    genre = title.split('(')[1].replace(')', '')
    title = title.split('(')[0]

    return {
        'Family': familyname,
        'Genre': genre,
        'Source': website,
        'Title': title,
    }

# %%
family_names = ["dofloo", "xorddos", "Darlloz", "lupper", "Gafgyt", "Luabot", "Kaiten", "Turla"]
table = []

for family in family_names:
    filterList = [f for f in html_files if f.find(family)>=0]
    print(family, len(filterList))
    for f in filterList:
        data = parse(f, family)
        table.append(data)

import pandas as pd
pd.DataFrame(table)
# Out:
# dofloo 5
# xorddos 6
# Darlloz 6
# lupper 4
# Gafgyt 8
# Luabot 8
# Kaiten 5
# Turla 4
#      Family     Genre                            Source  \
# 0    dofloo      news             bleepingcomputer.com
# 1    dofloo  analysis          blog.malwaremustdie.org
# 2    dofloo  analysis               blog.syscall.party
# 3    dofloo      news               securityaffairs.co
# 4    dofloo      tech                   trendmicro.com
# 5   xorddos      tech                    cdnetworks.com
# 6   xorddos      news                  crowdstrike.com
# 7   xorddos  analysis                      intezer.com
# 8   xorddos  analysis                    microsoft.com
# 9   xorddos      tech                   trendmicro.com
# 10  xorddos  analysis                   trendmicro.com
# 11  Darlloz  analysis                  blogs.cisco.com
# 12  Darlloz      news           community.broadcom.com
# 13  Darlloz      tech                         giac.org
# 14  Darlloz  analysis                            icc17
# 15  Darlloz      tech                   trendmicro.com
# 16  Darlloz      tech                   trendmicro.com
# 17   lupper      news                   securelist.com
# 18   lupper  analysis                     spamlaws.com
# 19   lupper      tech                   trendmicro.com
# 20   lupper      tech                  web.archive.org
# 21   Gafgyt  analysis                     fortinet.com
# 22   Gafgyt  analysis               nozominetworks.com
# 23   Gafgyt  analysis  resources.securityscorecard.com
# 24   Gafgyt  analysis                      sectrio.com
# 25   Gafgyt      tech                   trendmicro.com
# 26   Gafgyt  analysis      unit42.paloaltonetworks.com
# 27   Gafgyt  analysis      unit42.paloaltonetworks.com
# 28   Gafgyt      tech                    wikipedia.org
# 29   Luabot      news                     cyber.nj.gov
# 30   Luabot  analysis               malwaremustdie.org
# 31   Luabot      tech                    microsoft.com
# 32   Luabot      news               news.softpedia.com
# 33   Luabot  analysis               securityaffairs.co
# 34   Luabot      tech                   trendmicro.com
# 35   Luabot  analysis                 w00tsec.blogspot
# 36   Luabot      tech              xforce.ibmcloud.com
# 37   Kaiten      tech                      fsecure.com
# 38   Kaiten      tech                     lacework.com
# 39   Kaiten  analysis                     tarlogic.com
# 40   Kaiten  campaign                   trendmicro.com
# 41   Kaiten      tech                  trendmicro.com2
# 42    Turla      tech                  kcm.trellix.com
# 43    Turla  analysis                     leonardo.com
# 44    Turla  analysis                   securelist.com
# 45    Turla      tech                   trendmicro.com
#
#                                                 Title
# 0                 Exposed Docker APIs Abused by DDoS
# 1                          Reversing an ARM arch ELF
# 2       Analysing the new Linux_AES.DDoS IoT malware
# 3                  AESDDoS exploits CVE20193396 flaw
# 4                                Threat Encyclopedia
# 5                    Understanding a XOR.DDoS Attack
# 6     LinuxTargeted Malware Increases by 35p in 2021
# 7    Linux Backdoor RedXOR Likely Operated by Chin...
# 8    A deeper look at the stealthy DDoS malware ta...
# 9                                Threat Encyclopedia
# 10   XORDDoS, Kaiji Variants Target Exposed Docker...
# 11                                 Including Malware
# 12           Endpoint Protection Symantec Enterprise
# 13                  introduction linux based malware
# 14       IoT Sandbox To Analysis IoT malware Zollard
# 15                                    UNIX_DARLLOZ.A
# 16                             Worm_Linux_DARLLOZ.AA
# 17                              Linux.Lupper reports
# 18                                       Lupper Worm
# 19   Lupil_Lupper Worm Vulnerability  Threat Encyc...
# 20                                 Linux_Lupper.worm
# 21   Linux Gafgyt.B!tr Exploits Netcore Vulnerabil...
# 22   Could Threat Actors Be Downgrading Their Malw...
# 23   A Detailed Analysis Of The Gafgyt Malware Tar...
# 24                    Gafgyt Backdoor Malware report
# 25                        GAFGYT Threat Encyclopedia
# 26   Multiexploit IoT_Linux Botnets Mirai and Gafg...
# 27   Unit 42 Finds New Mirai and Gafgyt IoT_Linux ...
# 28                                Wikipedia BASHLITE
# 29                      NJCCIC Threat Profile LuaBot
# 30           2016 Linux_LuaBot IoT botnet as service
# 31        Backdoor_Linux_Luabot.A threat description
# 32   LuaBot Is the First DDoS Malware Coded in Lua...
# 33   LuaBot is the first Linux DDoS botnet written...
# 34      New Linux Malware Exploits CGI Vulnerability
# 35             LuaBot Malware targeting cable modems
# 36                          LuaBot Linux_IoT Malware
# 37                            Backdoor OSX Tsunami.A
# 38                          The Kek Security Network
# 39   Attackers Abuse MobileIron’s RCE to deliver K...
# 40   Exposed Docker Server Abused to Drop Cryptomi...
# 41     Backdoor.Linux.KAITEN.AMV Threat Encyclopedia
# 42                Trellix Insights The Penquin Turla
# 43       Malware Technical Insight Turla Penquin_x64
# 44                                 The Penquin Turla
# 45                BKDR_TURLA.YKX Threat Encyclopedia

# %%
".\dofloo bleepingcomputer.com - Exposed Docker APIs Abused by DDoS (news)".split('dofloo')
# Out:
# ['.\\', ' bleepingcomputer.com - Exposed Docker APIs Abused by DDoS (news)']

# %%
# export a csv that link doucument number, txt & html files
df = pd.DataFrame(table)
df['DocId'] = 'D,'
df['Txtname'] = ''
df = df.reindex(columns=['Family','DocId','Genre','Txtname','Source','Title'])
display(df.head(3))
# df.to_csv('0_info.csv', index=False)
# Out:
#    Family DocId     Genre Txtname                    Source  \
# 0  dofloo    D,      news             bleepingcomputer.com
# 1  dofloo    D,  analysis          blog.malwaremustdie.org
# 2  dofloo    D,  analysis               blog.syscall.party
#
#                                             Title
# 0             Exposed Docker APIs Abused by DDoS
# 1                      Reversing an ARM arch ELF
# 2   Analysing the new Linux_AES.DDoS IoT malware

# %% [markdown]
# ### list family document table

# %%
import pandas as pd
df = pd.read_csv('./0_info.csv')
df = df.sort_values(by=['DocId'])
df[['Family','DocId','Genre','Source','Title']]
# Out:
#      Family DocId     Genre                            Source  \
# 0    dofloo  D1,1      news             bleepingcomputer.com
# 1    dofloo  D1,2      news               securityaffairs.co
# 2    dofloo  D1,3  analysis               blog.syscall.party
# 3    dofloo  D1,4      tech                   trendmicro.com
# 4   xorddos  D2,1      tech                    cdnetworks.com
# 5   xorddos  D2,2      news                  crowdstrike.com
# 6   xorddos  D2,3  analysis                      intezer.com
# 7   xorddos  D2,4  analysis                    microsoft.com
# 8   xorddos  D2,5      tech                   trendmicro.com
# 9   xorddos  D2,6  analysis                   trendmicro.com
# 11  Darlloz  D3,1      news           community.broadcom.com
# 12  Darlloz  D3,2      tech                         giac.org
# 13  Darlloz  D3,3  analysis                            icc17
# 14  Darlloz  D3,4      tech                   trendmicro.com
# 15  Darlloz  D3,5      tech                   trendmicro.com
# 10  Darlloz  D3,6  analysis                  blogs.cisco.com
# 20   Gafgyt  D4,1  analysis                     fortinet.com
# 21   Gafgyt  D4,2  analysis               nozominetworks.com
# 23   Gafgyt  D4,3  analysis                      sectrio.com
# 22   Gafgyt  D4,4  analysis  resources.securityscorecard.com
# 24   Gafgyt  D4,5      tech                   trendmicro.com
# 25   Gafgyt  D4,6  analysis      unit42.paloaltonetworks.com
# 26   Gafgyt  D4,7  analysis      unit42.paloaltonetworks.com
# 27   Gafgyt  D4,8      tech                    wikipedia.org
# 28   Luabot  D5,1      news                     cyber.nj.gov
# 29   Luabot  D5,2  analysis               malwaremustdie.org
# 30   Luabot  D5,3      tech                    microsoft.com
# 31   Luabot  D5,4      news               news.softpedia.com
# 32   Luabot  D5,5  analysis               securityaffairs.co
# 33   Luabot  D5,6      tech                   trendmicro.com
# 34   Luabot  D5,7  analysis                 w00tsec.blogspot
# 35   Luabot  D5,8      tech              xforce.ibmcloud.com
# 36   Kaiten  D6,1      tech                      fsecure.com
# 37   Kaiten  D6,2      tech                     lacework.com
# 38   Kaiten  D6,3  analysis                     tarlogic.com
# 39   Kaiten  D6,4  campaign                   trendmicro.com
# 40   Kaiten  D6,5      tech                  trendmicro.com2
# 41    Turla  D7,1      tech                  kcm.trellix.com
# 42    Turla  D7,2  analysis                     leonardo.com
# 43    Turla  D7,3  analysis                   securelist.com
# 44    Turla  D7,4      tech                   trendmicro.com
# 16   lupper  D8,1      news                   securelist.com
# 17   lupper  D8,2  analysis                     spamlaws.com
# 18   lupper  D8,3      tech                   trendmicro.com
# 19   lupper  D8,4      tech                  web.archive.org
#
#                                                 Title
# 0                 Exposed Docker APIs Abused by DDoS
# 1                  AESDDoS exploits CVE20193396 flaw
# 2       Analysing the new Linux_AES.DDoS IoT malware
# 3                                Threat Encyclopedia
# 4                    Understanding a XOR.DDoS Attack
# 5     LinuxTargeted Malware Increases by 35p in 2021
# 6    Linux Backdoor RedXOR Likely Operated by Chin...
# 7    A deeper look at the stealthy DDoS malware ta...
# 8                                Threat Encyclopedia
# 9    XORDDoS, Kaiji Variants Target Exposed Docker...
# 11           Endpoint Protection Symantec Enterprise
# 12                  introduction linux based malware
# 13       IoT Sandbox To Analysis IoT malware Zollard
# 14                                    UNIX_DARLLOZ.A
# 15                             Worm_Linux_DARLLOZ.AA
# 10                                 Including Malware
# 20   Linux Gafgyt.B!tr Exploits Netcore Vulnerabil...
# 21   Could Threat Actors Be Downgrading Their Malw...
# 23                    Gafgyt Backdoor Malware report
# 22   A Detailed Analysis Of The Gafgyt Malware Tar...
# 24                        GAFGYT Threat Encyclopedia
# 25   Multiexploit IoT_Linux Botnets Mirai and Gafg...
# 26   Unit 42 Finds New Mirai and Gafgyt IoT_Linux ...
# 27                                Wikipedia BASHLITE
# 28                      NJCCIC Threat Profile LuaBot
# 29           2016 Linux_LuaBot IoT botnet as service
# 30        Backdoor_Linux_Luabot.A threat description
# 31   LuaBot Is the First DDoS Malware Coded in Lua...
# 32   LuaBot is the first Linux DDoS botnet written...
# 33      New Linux Malware Exploits CGI Vulnerability
# 34             LuaBot Malware targeting cable modems
# 35                          LuaBot Linux_IoT Malware
# 36                            Backdoor OSX Tsunami.A
# 37                          The Kek Security Network
# 38   Attackers Abuse MobileIron’s RCE to deliver K...
# 39   Exposed Docker Server Abused to Drop Cryptomi...
# 40     Backdoor.Linux.KAITEN.AMV Threat Encyclopedia
# 41                Trellix Insights The Penquin Turla
# 42       Malware Technical Insight Turla Penquin_x64
# 43                                 The Penquin Turla
# 44                BKDR_TURLA.YKX Threat Encyclopedia
# 16                              Linux.Lupper reports
# 17                                       Lupper Worm
# 18   Lupil_Lupper Worm Vulnerability  Threat Encyc...
# 19                                 Linux_Lupper.worm
